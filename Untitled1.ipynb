# %% [markdown]
# <a href="https://colab.research.google.com/github/hoa2995/khoavuong/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get remove -y openjdk-17-jdk-headless
# Cài đặt Java 21
# !apt-get install -y openjdk-21-jdk-headless
# !java -version
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !mkdir -p /home/server
# %cd /home/server
# !wget https://api.papermc.io/v2/projects/paper/versions/1.21.1/builds/123/downloads/paper-1.21.1-123.jar -O paper.jar
# Out:
# /home/server
# --2024-10-19 08:02:09--  https://api.papermc.io/v2/projects/paper/versions/1.21.1/builds/123/downloads/paper-1.21.1-123.jar
# Resolving api.papermc.io (api.papermc.io)... 104.26.12.138, 172.67.72.198, 104.26.13.138, ...
# Connecting to api.papermc.io (api.papermc.io)|104.26.12.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49379473 (47M) [application/java-archive]
# Saving to: ‘paper.jar’
#
# paper.jar           100%[===================>]  47.09M   171MB/s    in 0.3s
#
# 2024-10-19 08:02:09 (171 MB/s) - ‘paper.jar’ saved [49379473/49379473]

# %%
# !echo "eula=true" > eula.txt
# !java -Xmx50G -Xms16G -jar paper.jar nogui
# Out:
# Starting org.bukkit.craftbukkit.Main
# [08:06:34 INFO]: [bootstrap] Running Java 21 (OpenJDK 64-Bit Server VM 21.0.4+7-Ubuntu-1ubuntu222.04; Ubuntu null) on Linux 6.1.85+ (amd64)
# [08:06:34 INFO]: [bootstrap] Loading Paper 1.21.1-123-master@aebbdc9 (2024-10-16T14:15:18Z) for Minecraft 1.21.1
# [08:06:34 INFO]: [PluginInitializerManager] Initializing plugins...
# [08:06:35 INFO]: [PluginInitializerManager] Initialized 0 plugins
# [08:06:40 INFO]: [ReobfServer] Remapping server...
# [08:06:57 INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [08:06:58 INFO]: Found new data pack file/bukkit, loading it automatically
# [08:06:58 INFO]: Found new data pack paper, loading it automatically
# [08:07:02 INFO]: No existing world data, creating new world
# [08:07:07 INFO]: Loaded 1290 recipes
# [08:07:07 INFO]: [ReobfServer] Done remapping server in 27620ms.
# [08:07:07 INFO]: Loaded 1399 advancements
# ...

# %%
# !wget https://github.com/playit-cloud/playit-agent/releases/latest/download/playit-linux_64 -O playit
# !chmod +x playit
# !./playit
